, 137, 136, 137, 137, 138, 141, 142, 141, 140, 142, 141, 142, 141, 142, 142, 141, 138, 139, 139, 139, 141, 140, 142, 143, 142, 141, 141, 142, 141, 139, 138, 139, 140, 141, 140, 138, 137, 134, 134, 137, 140, 141, 140, 140, 139, 141, 142, 141, 137, 139, 138, 140, 139, 140, 140, 140, 140, 140, 140, 140, 140, 139, 139, 137, 135, 136, 135, 135, 136, 135, 134, 133, 135, 134, 132, 129, 131, 133, 132, 132, 131, 130, 129, 127, 126, 125, 123, 124, 123, 124, 124, 123, 121, 118, 119, 119, 119, 120, 120, 120, 115, 119, 119, 121, 120, 120, 120, 119, 119, 120, 118, 117, 117, 117, 118, 118, 115, 112, 107, 108, 110, 111, 111, 110, 110, 110, 111, 112, 110, 108, 104, 106, 107, 105, 101, 96, 94, 98, 101, 102, 104, 104, 105, 106, 108, 107, 105, 104, 105, 106, 103, 101, 99, 97, 100, 100, 98, 93, 94, 94, 95, 94, 92, 89, 91, 108, 113, 115, 118, 118, 119, 120, 117, 121, 120, 123, 126, 127, 127, 127, 124, 125, 128, 132, 133, 134, 134, 134, 133, 133, 131, 127, 133, 136, 136, 137, 139, 140, 139, 137, 137, 134, 135, 135, 136, 136, 137, 135, 137, 133, 136, 138, 142, 143, 144, 140, 143, 142, 141, 144, 142, 144, 143, 144, 145, 146, 147, 148, 149, 148, 144, 143, 142, 144, 145, 144, 143, 144, 149, 150, 149, 147, 149, 151, 150, 149, 146, 148, 148, 149, 148, 148, 144, 144, 144, 147, 147, 147, 143, 142, 143, 144, 146, 145, 146, 145, 147, 146, 145, 144, 143, 143, 145, 145, 144, 144, 144, 144, 146, 147, 146, 146, 144, 143, 146, 148, 153, 152, 151, 148, 149, 152, 152, 152, 152, 154, 156, 154, 152, 151, 156, 157, 158, 159, 158, 159, 158, 159]
img = np.array(img)
img2 = img.reshape(28,28)

# %%
import matplotlib.pyplot as plt
plt.imshow(img2, cmap='gray', vmin=0, vmax=255)

# %%
sunflower_path = f"D:\\TUM 2\\AIoT\\Project\\Collective dataset\\Extracted\\White\\New3\\2\\2_1_03751313.jpg"
#copypath2 = f"D:\\TUM 2\\AIoT\\Project\\Collective dataset\\temp3\\5\\_0_1790.jpg"
img = tf.keras.preprocessing.image.load_img(
    sunflower_path, target_size=(28, 28), color_mode='grayscale'
)
img2 = np.array(img)
#print(img2)
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

import matplotlib.pyplot as plt
plt.imshow(img2, cmap='gray')
dim = (160, 120)
resized = cv2.resize(img2, dim, interpolation = cv2.INTER_AREA)
dim = (20, 20)
resized = cv2.resize(resized, dim, interpolation = cv2.INTER_LINEAR)
plt.imshow(resized, cmap='gray')

# %%
import cv2
dim = (160, 120)
resized = cv2.resize(img2, dim, interpolation = cv2.INTER_AREA)
import matplotlib.pyplot as plt
plt.imshow(resized, cmap='gray')

# %%
reIm = resized
newIm = np.zeros((int(120/5), int(160/5)), dtype=int)
# for i in range(0, reIm.shape[0], 5):
#     newIm[int(i/5)] = (reIm[i] + reIm[i+1] + reIm[i+2] + reIm[i+3] + reIm[i+4])/5

# %%
# reIm = reIm.reshape(160,120)
# for i in range(newIm.shape[0]):
#     for j in range(newIm.shape[1]):
#         newIm[i, j] = (reIm[i*5, j*5] + reIm[i,j*5+1] + reIm[i,j*5+2] + reIm[i,j*5+3] + reIm[i,j*5+4])/5
    
# for j in range(newIm.shape[1]):
#     for i in range(newIm.shape[0]):
#         print(i)
#         print(j)
#         newIm[i, j] = (reIm[i*5, j] + reIm[i*5+1,j] + reIm[i*5+2,j] + reIm[i*5+3,j] + reIm[i*5+4,j])/5

# %%
# for i in range(newIm.shape[0]):
#     for j in range(newIm.shape[1]):
#         temp = (reIm[i*5, j*5] + reIm[i*5+1,j*5+1] + reIm[i*5+2,j*5+2] + reIm[i*5+3,j*5+3] + reIm[i*5+4,j*5+4])
#         print(temp)
#         if(temp>=255):
#             newIm[i, j] = 255
#         else:
#             newIm[i, j] = 0

# %%
finalIm = np.zeros((28, 28))
finalIm[:,] = newIm[:,]

# %%
plt.imshow(newIm, cmap='gray')

# %%
reIm = resized
counter =0
for i in range(newIm.shape[0]):
    for j in range(newIm.shape[1]):
        newIm[i, j] = reIm[i*5,j*5]
        counter += 1
print(counter)    
# for j in range(newIm.shape[1]):
#     for i in range(newIm.shape[0]):
#         newIm[i, j] = reIm[i*5,j]
# Out:
# 768

# %%
(T, im_thresh) = cv2.threshold(reIm, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)
plt.imshow(im_thresh,'gray',vmin=0,vmax=255)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [84], in <cell line: 1>()
# ----> 1 (T, im_thresh) = cv2.threshold(reIm, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)
#       2 plt.imshow(im_thresh,'gray',vmin=0,vmax=255)
#
# error: OpenCV(4.6.0) :-1: error: (-5:Bad argument) in function 'threshold'
# > Overload resolution failed:
# >  - src is not a numerical tuple
# >  - Expected Ptr<cv::UMat> for argument 'src'

# %%
plt.imshow(cProcess, cmap='gray')

# %%
re
Im.shape
# Out:
# (120, 160)

# %%
x = 160/28
y = 120/28
print(x, y)
# Out:
# 5.714285714285714 4.285714285714286

# %%
reIm =resized
for i in range(finalIm.shape[0]):
    for j in range(finalIm.shape[1]):
        finalIm[i, j] = reIm[int(i*y),int(j*x)]
        counter += 1

# %%
z = 160*120/(28*28)
flat = resized.reshape(160*120,)
flat_out = np.zeros((28*28,))

# %%
for i in range(flat_out.shape[0]):
    flat_out[i] = flat[int(i*z)]

# %%
flat_out_reshaped = flat_out.reshape(28,28)

# %%
flat2 = resized.reshape(160*120, 1)
data = flat2
with open('input3.txt', 'w') as outfile:
    # I'm writing a header here just for the sake of readability
    # Any line starting with "#" will be ignored by numpy.loadtxt
    #outfile.write('# Array shape: {0}\n'.format(w.shape))
    outfile.write('{')
    # Iterating through a ndimensional array produces slices along
    # the last axis. This is equivalent to data[i,:,:] in this case
    i=0
    for data_slice in data:
        # The formatting string indicates that I'm writing out
        # the values in left-justified columns 7 characters in width
        # with 2 decimal places.
        
        #np.savetxt(outfile, data_slice, fmt='%-4d')
        outfile.write(str((np.int16(data_slice[0]))))
        # Writing out a break to indicate different slices...
        i += 1
        if(i%25==0):
            outfile.write(',\n')
        else:
            outfile.write(', ')
        
    outfile.write('}')

# %%
np.savetxt('FlatArray2.txt',(np.int16(flat2)), fmt='%4d')

# %%
flat.shape
# Out:
# (19200,)

# %%
open('temp.txt', 'w').write(str(np.int16(flat)))
# Out:
# 17

# %%
reIm.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1